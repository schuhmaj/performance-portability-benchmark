# %% [markdown]
# This notebook was made for plotting nBodySimulation results.

# %%
import subprocess
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import re

import benchmarking_nBody

# %% [markdown]
# Choose which methods to include. The currently supported options are vulkan_cells, vulkan_naive, cpp_naive
#
# Also choose whether or not to force rerun the benchmarks. Alternatively, old runs will be used (if available)

# %%
incl = ["vulkan_naive", "vulkan_cells", "vulkan_verlet", "slang->vulkan_naive", "slang->vulkan_cells", "slang->vulkan_verlet", "slang->ptx_naive", "slang->ptx_cells", "slang->ptx_verlet", "cpp_naive"]
force_rerun         = False
search_hyper_params = False
draw_mean           = True

executables = {
    "vulkan_naive"         : "../build/src/nBodySimulation/vulkan/naive/nbody_vulkan_naive",
    "vulkan_cells"         : "../build/src/nBodySimulation/vulkan/cell_lists/nbody_vulkan_cells",
    "vulkan_verlet"        : "../build/src/nBodySimulation/vulkan/verlet_lists/nbody_vulkan_verlet",
    "slang->vulkan_naive"  : "../build/src/nBodySimulation/slang/naive/nbody_slang_vulkan_naive", 
    "slang->vulkan_cells"  : "../build/src/nBodySimulation/slang/cell_lists/nbody_slang_vulkan_cells", 
    "slang->vulkan_verlet" : "../build/src/nBodySimulation/slang/verlet_lists/nbody_slang_vulkan_verlet", 
    "slang->ptx_naive"     : "../build/src/nBodySimulation/slang/naive/nbody_slang_cuda_naive", 
    "slang->ptx_cells"     : "../build/src/nBodySimulation/slang/cell_lists/nbody_slang_cuda_cells", 
    "slang->ptx_verlet"    : "../build/src/nBodySimulation/slang/verlet_lists/nbody_slang_cuda_verlet", 
    "cpp_naive"            : "../build/src/nBodySimulation/cpp/nbody_cpp"
}

tests = {
    "vulkan_naive"         : "../build/test/nBodySimulation/vulkan/naive/nbody_vulkan_naive_test",
    "vulkan_cells"         : "../build/test/nBodySimulation/vulkan/cell_lists/nbody_vulkan_cells_test",
    "vulkan_verlet"        : "../build/test/nBodySimulation/vulkan/verlet_lists/nbody_vulkan_verlet_test",
    "slang->vulkan_naive"  : "../build/test/nBodySimulation/slang/vulkan/naive/nbody_slang_vulkan_naive_test", 
    "slang->vulkan_cells"  : "../build/test/nBodySimulation/slang/vulkan/cell_lists/nbody_slang_vulkan_cells_test", 
    "slang->vulkan_verlet" : "../build/test/nBodySimulation/slang/vulkan/verlet_lists/nbody_slang_vulkan_verlet_test", 
    "slang->ptx_naive"     : "../build/test/nBodySimulation/slang/cuda/naive/nbody_slang_cuda_naive_test", 
    "slang->ptx_cells"     : "../build/test/nBodySimulation/slang/cuda/cell_lists/nbody_slang_cuda_cells_test", 
    "slang->ptx_verlet"    : "../build/test/nBodySimulation/slang/cuda/verlet_lists/nbody_slang_cuda_verlet_test", 
    "cpp_naive"            : "../build/test/nBodySimulation/cpp/nbody_cpp_test"

}

results = {
    "vulkan_naive"         : "../results/nBody_vulkan_naive.json",
    "vulkan_cells"         : "../results/nBody_vulkan_cells.json",
    "vulkan_verlet"        : "../results/nBody_vulkan_verlet.json",
    "slang->vulkan_naive"  : "../results/nBody_slang_vulkan_naive.json", 
    "slang->vulkan_cells"  : "../results/nBody_slang_vulkan_cells.json", 
    "slang->vulkan_verlet" : "../results/nBody_slang_vulkan_verlet.json", 
    "slang->ptx_naive"     : "../results/nBody_slang_cuda_naive.json", 
    "slang->ptx_cells"     : "../results/nBody_slang_cuda_cells.json", 
    "slang->ptx_verlet"    : "../results/nBody_slang_cuda_verlet.json", 
    "cpp_naive"            : "../results/nBody_cpp_naive.json"
}

# %%
def run_benchmark(method):
    print("Now running " + method + " benchmark...")
    executable_path = executables[method]
    result_path = results[method]
    command = [executable_path, f"--benchmark_out={result_path}", "--benchmark_out_format=json"]
    result = subprocess.run(command, capture_output=True, text=True, check=True)
    print(result.stdout, "\n")

def file_exists(filepath):
    return os.path.exists(filepath)

def validate_json_file(method):
    try:
        with open(results[method]) as f:
            json.load(f)
        return True
    except:
        return False

# %%
benchmarking_nBody.run_cmake()
if force_rerun:
    for method in incl:
        if not file_exists(executables[method]):
            raise FileNotFoundError(f"The executable for {method} was not found in the build directory. Reconfigure the project to build the correct files!")
    for method in incl:
        run_benchmark(method=method)
else:
    for method in incl:
        if not file_exists(results[method]):
            print(f"Could not find results for {method}...")
            if not file_exists(executables[method]):
                raise FileNotFoundError(f"The executable for {method} was not found in the build directory. Reconfigure the project to build the correct files!")
            run_benchmark(method)
        if not validate_json_file(method):
            print(f"Could not validate json results file for {method}.")
            run_benchmark(method)

for method in incl:
    if not validate_json_file(method):
        raise FileNotFoundError(f"The result file for {method} was not found or could not be opened.")
# Out:
#  ________________________________________
# / I distinctly remember forgetting that. \
# \ -Clara Barton                          /
#  ----------------------------------------
#       \                    / \  //\
#        \    |\___/|      /   \//  \\
#             /0  0  \__  /    //  | \ \
#            /     /  \/_/    //   |  \  \
#            @_^_@'/   \/_   //    |   \   \
#            //_^_/     \/_ //     |    \    \
#         ( //) |        \///      |     \     \
#       ( / /) _|_ /   )  //       |      \     _\
#     ( // /) '/,_ _ _/  ( ; -.    |    _ _\.-~        .-~~~^-.
#   (( / / )) ,-{        _      `-.|.-~-.           .~         `.
#  (( // / ))  '/\      /                 ~-. _ .-~      .-~^-.  \
#  (( /// ))      `.   {            }                   /      \  \
#   (( / ))     .----~-.\        \-'                 .~         \  `. \^-.
#              ///.----..>        \             _ -~             `.  ^-`  ^-_
#                ///-._ _ _ _ _ _ _}^ - - - - ~                     ~-- ,.-~
#                                                                   /.-~
# [1/122] Compile vulkan compute shader from file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelVerlet.comp' to '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelVerlet.comp.spv'.
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelVerlet.comp
# [2/122] Compile vulkan compute shader from file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelCountNeighbors.comp' to '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelCountNeighbors.comp.spv'.
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelCountNeighbors.comp
# [3/122] Slang -> CUDA header (.ptx): KernelVelocity
# [4/122] Slang -> CUDA header (.ptx): KernelBlockSum
# [5/122] Slang -> CUDA header (.ptx): KernelForce
# [6/122] Slang -> CUDA header (.ptx): KernelHistogram
# [7/122] Slang -> CUDA header (.ptx): KernelIdCells
# [8/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/naive/KernelForce.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/naive/KernelForce.h'.
# -- Interpreting shader in little endian...
# [9/122] Slang -> CUDA header (.ptx): KernelVerlet
# [10/122] Slang -> CUDA header (.ptx): KernelVelocity
# [11/122] Slang -> CUDA header (.ptx): KernelVelocity
# [12/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/naive/KernelVelocity.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/naive/KernelVelocity.h'.
# -- Interpreting shader in little endian...
# [13/122] Slang -> CUDA header (.ptx): KernelPosition
# [14/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/naive/KernelPosition.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/naive/KernelPosition.h'.
# -- Interpreting shader in little endian...
# [15/122] Slang -> CUDA header (.ptx): KernelForce
# [16/122] Slang -> CUDA header (.ptx): KernelCountNeighbors
# [17/122] Slang -> CUDA header (.ptx): KernelBlockSum
# [18/122] Slang -> CUDA header (.ptx): KernelBlellochScan
# [19/122] Slang -> CUDA header (.ptx): KernelBlellochScan
# [20/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelResetCells.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelResetCells.h'.
# -- Interpreting shader in little endian...
# [21/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelIdCells.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelIdCells.h'.
# -- Interpreting shader in little endian...
# [22/122] Slang -> CUDA header (.ptx): KernelPosition
# [23/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelVelocity.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelVelocity.h'.
# -- Interpreting shader in little endian...
# [24/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelPosition.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelPosition.h'.
# -- Interpreting shader in little endian...
# [25/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelBlellochScan.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelBlellochScan.h'.
# -- Interpreting shader in little endian...
# [26/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelBlockSum.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelBlockSum.h'.
# -- Interpreting shader in little endian...
# [27/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelHistogram.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelHistogram.h'.
# -- Interpreting shader in little endian...
# [28/122] Slang -> CUDA header (.ptx): KernelForce
# [29/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelForce.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelForce.h'.
# -- Interpreting shader in little endian...
# [30/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelVelocity.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelVelocity.h'.
# -- Interpreting shader in little endian...
# [31/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelForce.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/cell_lists/KernelForce.h'.
# -- Interpreting shader in little endian...
# [32/122] Slang -> CUDA header (.ptx): KernelResetCells
# [33/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelResetCells.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelResetCells.h'.
# -- Interpreting shader in little endian...
# [34/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelVelocity.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelVelocity.h'.
# -- Interpreting shader in little endian...
# [35/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelPosition.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelPosition.h'.
# -- Interpreting shader in little endian...
# [36/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/naive/generated_shaders/KernelVelocity.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/naive/KernelVelocity.h'.
# -- Interpreting shader in little endian...
# [37/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelBlellochScan.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelBlellochScan.h'.
# -- Interpreting shader in little endian...
# [38/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelBlockSum.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelBlockSum.h'.
# -- Interpreting shader in little endian...
# [39/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelCountNeighbors.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelCountNeighbors.h'.
# -- Interpreting shader in little endian...
# [40/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelVerlet.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/vulkan/verlet_lists/KernelVerlet.h'.
# -- Interpreting shader in little endian...
# [41/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/naive/generated_shaders/KernelForce.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/naive/KernelForce.h'.
# -- Interpreting shader in little endian...
# [42/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/naive/generated_shaders/KernelPosition.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/naive/KernelPosition.h'.
# -- Interpreting shader in little endian...
# [43/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelForce.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelForce.h'.
# -- Interpreting shader in little endian...
# [44/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelPosition.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelPosition.h'.
# -- Interpreting shader in little endian...
# [45/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelBlellochScan.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelBlellochScan.h'.
# -- Interpreting shader in little endian...
# [46/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelBlockSum.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelBlockSum.h'.
# -- Interpreting shader in little endian...
# [47/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelHistogram.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelHistogram.h'.
# -- Interpreting shader in little endian...
# [48/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/generated_shaders/KernelIdCells.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/cell_lists/KernelIdCells.h'.
# -- Interpreting shader in little endian...
# [49/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelVelocity.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelVelocity.h'.
# -- Interpreting shader in little endian...
# [50/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelBlockSum.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelBlockSum.h'.
# -- Interpreting shader in little endian...
# [51/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelVerlet.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelVerlet.h'.
# -- Interpreting shader in little endian...
# [52/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelPosition.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelPosition.h'.
# -- Interpreting shader in little endian...
# [53/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelCountNeighbors.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelCountNeighbors.h'.
# -- Interpreting shader in little endian...
# [54/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelForce.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelForce.h'.
# -- Interpreting shader in little endian...
# [55/122] Converting compiled shader '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/generated_shaders/KernelBlellochScan.comp.spv' to header file '/home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/build/src/nBodySimulation/slang/verlet_lists/KernelBlellochScan.h'.
# -- Interpreting shader in little endian...
# [56/122] Slang -> CUDA header (.ptx): KernelPosition
# [57/122] Building CXX object src/nBodySimulation/cpp/CMakeFiles/nbody_cpp_lib.dir/Impl_Cpp.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/cpp/Impl_Cpp.h:10,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/cpp/Impl_Cpp.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [58/122] Building CXX object src/nBodySimulation/slang/naive/CMakeFiles/nbody_slang_vulkan_naive.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/naive/Impl_Slang_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/naive/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [59/122] Building CXX object src/nBodySimulation/vulkan/verlet_lists/CMakeFiles/nbody_vulkan_verlet.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/verlet_lists/Impl_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/verlet_lists/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [60/122] Linking CXX static library src/nBodySimulation/cpp/libnbody_cpp_lib.a
# [61/122] Building CXX object src/nBodySimulation/slang/naive/CMakeFiles/nbody_slang_vulkan_naive_lib.dir/Impl_Slang_Vulkan.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/naive/Impl_Slang_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/naive/Impl_Slang_Vulkan.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [62/122] Linking CXX static library src/nBodySimulation/slang/naive/libnbody_slang_vulkan_naive_lib.a
# [63/122] Building CXX object src/nBodySimulation/vulkan/cell_lists/CMakeFiles/nbody_vulkan_cells.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/cell_lists/Impl_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/cell_lists/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [64/122] Building CXX object src/nBodySimulation/vulkan/naive/CMakeFiles/nbody_vulkan_naive_lib.dir/Impl_Vulkan.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/naive/Impl_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/naive/Impl_Vulkan.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [65/122] Building CXX object src/nBodySimulation/vulkan/naive/CMakeFiles/nbody_vulkan_naive.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/naive/Impl_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/naive/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [66/122] Linking CXX static library src/nBodySimulation/vulkan/naive/libnbody_vulkan_naive_lib.a
# [67/122] Building CXX object src/nBodySimulation/vulkan/cell_lists/CMakeFiles/nbody_vulkan_cells_lib.dir/Impl_Vulkan.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/cell_lists/Impl_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/cell_lists/Impl_Vulkan.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [68/122] Linking CXX static library src/nBodySimulation/vulkan/cell_lists/libnbody_vulkan_cells_lib.a
# [69/122] Building CXX object src/nBodySimulation/slang/verlet_lists/CMakeFiles/nbody_slang_vulkan_verlet_lib.dir/Impl_Slang_Vulkan.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/Impl_Slang_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/Impl_Slang_Vulkan.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [70/122] Linking CXX static library src/nBodySimulation/slang/verlet_lists/libnbody_slang_vulkan_verlet_lib.a
# [71/122] Building CXX object src/nBodySimulation/vulkan/verlet_lists/CMakeFiles/nbody_vulkan_verlet_lib.dir/Impl_Vulkan.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/verlet_lists/Impl_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/vulkan/verlet_lists/Impl_Vulkan.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [72/122] Linking CXX static library src/nBodySimulation/vulkan/verlet_lists/libnbody_vulkan_verlet_lib.a
# [73/122] Building CXX object src/nBodySimulation/slang/cell_lists/CMakeFiles/nbody_slang_vulkan_cells_lib.dir/Impl_Slang_Vulkan.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/cell_lists/Impl_Slang_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/cell_lists/Impl_Slang_Vulkan.cpp:1:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [74/122] Linking CXX static library src/nBodySimulation/slang/cell_lists/libnbody_slang_vulkan_cells_lib.a
# [75/122] Building CXX object src/nBodySimulation/cpp/CMakeFiles/nbody_cpp.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/cpp/Impl_Cpp.h:10,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/cpp/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [76/122] Building CUDA object src/nBodySimulation/slang/naive/CMakeFiles/nbody_slang_cuda_naive.dir/main.cu.o
# ptxas info    : 0 bytes gmem
# [77/122] Building CUDA object src/nBodySimulation/slang/naive/CMakeFiles/nbody_slang_cuda_naive_lib.dir/Impl_Slang_Cuda.cu.o
# ptxas info    : 0 bytes gmem
# [78/122] Building CUDA object src/nBodySimulation/slang/cell_lists/CMakeFiles/nbody_slang_cuda_cells_lib.dir/Impl_Slang_Cuda.cu.o
# ptxas info    : 0 bytes gmem
# [79/122] Linking CXX static library src/nBodySimulation/slang/naive/libnbody_slang_cuda_naive_lib.a
# [80/122] Building CXX object src/nBodySimulation/slang/cell_lists/CMakeFiles/nbody_slang_vulkan_cells.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/cell_lists/Impl_Slang_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/cell_lists/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [81/122] Linking CXX executable src/nBodySimulation/vulkan/naive/nbody_vulkan_naive
# [82/122] Linking CXX static library src/nBodySimulation/slang/cell_lists/libnbody_slang_cuda_cells_lib.a
# [83/122] Linking CXX executable src/nBodySimulation/vulkan/cell_lists/nbody_vulkan_cells
# [84/122] Linking CXX executable src/nBodySimulation/slang/cell_lists/nbody_slang_vulkan_cells
# [85/122] Linking CXX executable src/nBodySimulation/vulkan/verlet_lists/nbody_vulkan_verlet
# [86/122] Linking CXX executable src/nBodySimulation/slang/naive/nbody_slang_vulkan_naive
# [87/122] Linking CXX executable src/nBodySimulation/cpp/nbody_cpp
# [88/122] Linking CXX executable CMakeFiles/nbody_slang_cuda_naive.dir/cmake_device_link.o
# [89/122] Building CUDA object src/nBodySimulation/slang/cell_lists/CMakeFiles/nbody_slang_cuda_cells.dir/main.cu.o
# ptxas info    : 0 bytes gmem
# [90/122] Linking CXX executable src/nBodySimulation/slang/naive/nbody_slang_cuda_naive
# [91/122] Building CUDA object src/nBodySimulation/slang/verlet_lists/CMakeFiles/nbody_slang_cuda_verlet_lib.dir/Impl_Slang_Cuda.cu.o
# ptxas info    : 0 bytes gmem
# [92/122] Linking CXX static library src/nBodySimulation/slang/verlet_lists/libnbody_slang_cuda_verlet_lib.a
# [93/122] Linking CXX executable CMakeFiles/nbody_slang_cuda_cells.dir/cmake_device_link.o
# [94/122] Building CXX object src/nBodySimulation/slang/verlet_lists/CMakeFiles/nbody_slang_vulkan_verlet.dir/main.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/Particle.h:9,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/NBodySimulation.h:21,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/Impl_Slang_Vulkan.h:2,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/nBodySimulation/slang/verlet_lists/main.cpp:2:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [95/122] Linking CXX executable src/nBodySimulation/slang/cell_lists/nbody_slang_cuda_cells
# [96/122] Linking CXX executable src/nBodySimulation/slang/verlet_lists/nbody_slang_vulkan_verlet
# [97/122] Building CXX object test/nBodySimulation/cpp/CMakeFiles/nbody_cpp_test.dir/CppNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/cpp/CppNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [98/122] Linking CXX executable test/nBodySimulation/cpp/nbody_cpp_test
# [99/122] Building CUDA object src/nBodySimulation/slang/verlet_lists/CMakeFiles/nbody_slang_cuda_verlet.dir/main.cu.o
# ptxas info    : 0 bytes gmem
# [100/122] Linking CXX executable CMakeFiles/nbody_slang_cuda_verlet.dir/cmake_device_link.o
# [101/122] Linking CXX executable src/nBodySimulation/slang/verlet_lists/nbody_slang_cuda_verlet
# [102/122] Building CXX object test/nBodySimulation/vulkan/naive/CMakeFiles/nbody_vulkan_naive_test.dir/VulkanNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/vulkan/naive/VulkanNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [103/122] Building CXX object test/nBodySimulation/vulkan/cell_lists/CMakeFiles/nbody_vulkan_cells_test.dir/VulkanNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/vulkan/cell_lists/VulkanNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [104/122] Linking CXX executable test/nBodySimulation/vulkan/naive/nbody_vulkan_naive_test
# [105/122] Linking CXX executable test/nBodySimulation/vulkan/cell_lists/nbody_vulkan_cells_test
# [106/122] Building CUDA object test/nBodySimulation/slang/cuda/naive/CMakeFiles/nbody_slang_cuda_naive_test.dir/SlangCudaNBodyTest.cu.o
# ptxas info    : 0 bytes gmem
# [107/122] Building CXX object test/nBodySimulation/vulkan/verlet_lists/CMakeFiles/nbody_vulkan_verlet_test.dir/VulkanNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/vulkan/verlet_lists/VulkanNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [108/122] Linking CXX executable CMakeFiles/nbody_slang_cuda_naive_test.dir/cmake_device_link.o
# [109/122] Building CUDA object test/nBodySimulation/slang/cuda/cell_lists/CMakeFiles/nbody_slang_cuda_cells_test.dir/SlangCudaNBodyTest.cu.o
# ptxas info    : 0 bytes gmem
# [110/122] Linking CXX executable test/nBodySimulation/vulkan/verlet_lists/nbody_vulkan_verlet_test
# [111/122] Linking CXX executable test/nBodySimulation/slang/cuda/naive/nbody_slang_cuda_naive_test
# [112/122] Linking CXX executable CMakeFiles/nbody_slang_cuda_cells_test.dir/cmake_device_link.o
# [113/122] Linking CXX executable test/nBodySimulation/slang/cuda/cell_lists/nbody_slang_cuda_cells_test
# [114/122] Building CXX object test/nBodySimulation/slang/vulkan/cell_lists/CMakeFiles/nbody_slang_vulkan_cells_test.dir/SlangVulkanNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/slang/vulkan/cell_lists/SlangVulkanNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [115/122] Linking CXX executable test/nBodySimulation/slang/vulkan/cell_lists/nbody_slang_vulkan_cells_test
# [116/122] Building CXX object test/nBodySimulation/slang/vulkan/naive/CMakeFiles/nbody_slang_vulkan_naive_test.dir/SlangVulkanNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/slang/vulkan/naive/SlangVulkanNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [117/122] Building CXX object test/nBodySimulation/slang/vulkan/verlet_lists/CMakeFiles/nbody_slang_vulkan_verlet_test.dir/SlangVulkanNBodyTest.cpp.o
# In file included from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/GoogleTestMatcher.h:3,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/NBodyTest.h:6,
#                  from /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/test/nBodySimulation/slang/vulkan/verlet_lists/SlangVulkanNBodyTest.cpp:4:
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘host’ attribute directive ignored [-Wattributes]
#    73 |     __attribute__((host)) __attribute__((device)) inline T ceilDiv(const T &a, const T &b) {
#       |                                                                                          ^
# /home/moritzbeste/Documents/projects/uni/bachelorarbeit/performance-portability-benchmark/src/common/UtilityFloatArithmetic.h:73:90: warning: ‘device’ attribute directive ignored [-Wattributes]
# [118/122] Linking CXX executable test/nBodySimulation/slang/vulkan/naive/nbody_slang_vulkan_naive_test
# [119/122] Linking CXX executable test/nBodySimulation/slang/vulkan/verlet_lists/nbody_slang_vulkan_verlet_test
# [120/122] Building CUDA object test/nBodySimulation/slang/cuda/verlet_lists/CMakeFiles/nbody_slang_cuda_verlet_test.dir/SlangCudaNBodyTest.cu.o
# ptxas info    : 0 bytes gmem
# [121/122] Linking CXX executable CMakeFiles/nbody_slang_cuda_verlet_test.dir/cmake_device_link.o
# [122/122] Linking CXX executable test/nBodySimulation/slang/cuda/verlet_lists/nbody_slang_cuda_verlet_test

# %% [markdown]
# Now all results should exist. Next the files need to be read.

# %%
def add_problem_size_column(df):
    df = df.copy()

    df = df[~df["name"].str.contains(r"_(?:mean|median|stddev)$", regex=True)]
    extracted = df["name"].str.extract(r"/(\d+)(?:/|$)")[0]

    if extracted.isna().any():
        bad = df.loc[extracted.isna(), "name"].unique()
        raise ValueError(f"Could not extract problem size N from:\n{bad}")

    df["N"] = extracted.astype(int)
    return df


def add_problem_size_column_mean_only(df):
    df = df.copy()

    df = df[df["name"].str.contains(r"mean$", regex=True)]
    extracted = df["name"].str.extract(r"/(\d+)(?:/|_)")[0]

    if extracted.isna().any():
        bad = df.loc[extracted.isna(), "name"].unique()
        raise ValueError(f"Could not extract N from:\n{bad}")

    df["N"] = extracted.astype(int)
    return df

# %%
def get_dataframes():    
    dataframes = {}
    for method in incl:
        with open(results[method], 'r') as f:
            data = json.load(f)
        benchmarks = data["benchmarks"]
        
        df = pd.DataFrame(benchmarks)
        if draw_mean:
            df = df[df["name"].str.endswith("_mean")]
        else:
            df = df[df["run_type"] == "iteration"]
        df = df.drop(columns=["family_index", "per_family_instance_index", "run_name", 
            "run_type", "repetitions", "repetition_index", 
            "threads", "iterations", "cpu_coefficient", 
            "real_coefficient", "big_o", "rms", 
            "aggregate_name", "aggregate_unit"])
        df["real_time_s"] = df["real_time"] / 1e9
        df["cpu_time_s"]  = df["cpu_time"]  / 1e9

        if draw_mean:
            dataframes[method] = add_problem_size_column_mean_only(df)
        else:
            dataframes[method] = add_problem_size_column(df)
    return dataframes

# %% [markdown]
# Now we display the results in matplotlib graphs.

# %%
def plot_single(df, title, git_hash=None):
    plt.figure(figsize=(8,5))
    plt.plot(df["N"], df["real_time_s"], marker="o")
    plt.xscale("log")
    plt.xlabel("N (problem size)")
    plt.ylabel("Real time (s)")
    plt.title(title)
    plt.grid(True)

    if git_hash:
        plt.figtext(
            0.5, -0.05,
            f"git hash: {git_hash}",
            ha="center", fontsize=8, color="gray"
        )

    plt.show()

def plot_overlay(dataframes, git_hash=None):
    plt.figure(figsize=(8,5))

    for label, df in dataframes.items():
        df = add_problem_size_column_mean_only(df)
        plt.plot(df["N"], df["real_time_s"], marker="o", label=label)

    plt.xscale("log")
    plt.xlabel("N (problem size)")
    plt.ylabel("Real time (s)")
    plt.title("Benchmark Comparison")
    plt.grid(True)
    plt.legend()

    if git_hash:
        plt.figtext(
            0.5, -0.05,
            f"git hash: {git_hash}",
            ha="center", fontsize=8, color="gray"
        )

    plt.show()

# %%
git_hash = subprocess.check_output(["git", "rev-parse", "HEAD"], text=True).strip()
if search_hyper_params:
    print("searching hyper parameters...")

    print("Searching hyper parameter TILE_SIZE...")
    incl_search_TILE_SIZE = ["vulkan_verlet", "slang->vulkan_verlet", "vulkan_cells", "slang->vulkan_cells", "slang->ptx_cells", "slang->ptx_verlet"]
    search_range_TILE_SIZE = [2**i for i in range(4, 11)]
    dataframes_TILE_SIZE = benchmarking_nBody.search_TILE_SIZE(executables, incl_search_TILE_SIZE, search_range_TILE_SIZE)
    benchmarking_nBody.plot_summary(dataframes_TILE_SIZE, groupby="TILE_SIZE", xlabel="TILE_SIZE", title="TILE_SIZE vs real time")

    print("Searching hyper parameter h...")
    incl_search_h = ["vulkan_cells", "slang->vulkan_cells", "slang->ptx_cells"]
    search_range_h = [9.0 * i for i in range(1, 17)]
    dataframes_h = benchmarking_nBody.search_h(executables, incl_search_h, search_range_h)
    benchmarking_nBody.plot_summary(dataframes_h, groupby="h", xlabel="h", title="h vs real time")

    print("Searching hyper parameter influenceRadius...")
    incl_search_inflRad = ["vulkan_verlet", "slang->vulkan_verlet", "slang->ptx_verlet"]
    search_range_inflRad = [4.0 * i for i in range(1, 17)]
    dataframes_inflRad = benchmarking_nBody.search_influenceRadius(executables, incl_search_inflRad, search_range_inflRad)
    benchmarking_nBody.plot_summary(dataframes_inflRad, groupby="Influence Radius", xlabel="Influence Radius", title="Influence Radius vs real time")

    print("Searching hyper parameter interval_neighbor_search...")
    incl_search_interval = ["vulkan_verlet", "slang->vulkan_verlet", "vulkan_cells", "slang->vulkan_cells"]
    search_range_interval = [5 * i for i in range(1, 10)]
    highest_pass = benchmarking_nBody.search_interval_neighbor_search(executables=tests, incl=incl_search_interval, search_range=search_range_interval)
    print("Highest passing interval_neighbor_search:", highest_pass)

    # reset constants
    old_tile_size = int(benchmarking_nBody.find_const_in_file("TILE_SIZE"))
    new_tile_size = 256
    benchmarking_nBody.update_tile_size(old_tile_size=old_tile_size, new_tile_size=new_tile_size)

    old_h = float(benchmarking_nBody.find_const_in_file(search_string="FloatType h"))
    h = 9.0
    new_conf_line_h = f"FloatType h{{{h}}};"
    old_conf_line_h = f"FloatType h{{{old_h}}};"
    benchmarking_nBody.repl(old=old_conf_line_h, new=new_conf_line_h)

    old_inflRad = float(benchmarking_nBody.find_const_in_file(search_string="FloatType influenceRadius"))
    inflRad = 4.0
    new_conf_line_inflRad = f"FloatType influenceRadius{{{inflRad}}};"
    old_conf_line_inflRad = f"FloatType influenceRadius{{{old_inflRad}}};"
    benchmarking_nBody.repl(old=old_conf_line_inflRad, new=new_conf_line_inflRad)

    old_interval = int(benchmarking_nBody.find_const_in_file(search_string="static constexpr uint interval_neighbor_search"))
    interval = 10
    new_conf_line_interval = f"static constexpr uint interval_neighbor_search{{{interval}}};"
    old_conf_line_interval = f"static constexpr uint interval_neighbor_search{{{old_interval}}};"
    benchmarking_nBody.repl(old=old_conf_line_interval, new=new_conf_line_interval)

# %%
dataframes = get_dataframes()
for method in incl:
    plot_single(dataframes[method], method, git_hash)
plot_overlay(dataframes, git_hash)
