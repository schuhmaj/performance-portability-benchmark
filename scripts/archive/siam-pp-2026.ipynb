# %% [markdown]
# # SIAM PP 2026 - Presentation - Plots

# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Iterable, Tuple

from seaborn import color_palette

import plot_benchmark
from pathlib import Path
import os

# %load_ext autoreload
# %autoreload
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# First, we merge the data and accumulate it into a single dataframe for analysis.

# %%
results_time = {
    "RTX2080" : Path("../results/rtx2080/RTX2080_Benchmark_Result.csv"),
    "RTX3080" : Path("../results/rtx3080/RTX3080_Benchmark_Result.csv"),
    "RTX4060" : Path("../results/rtx4060/RTX4060_Benchmark_Result.csv"),
    "RTX5080" : Path("../results/rtx5080/RTX5080_Benchmark_Result.csv"),
}
dfs = []
for gpu, path in results_time.items():
    dfs.append(pd.read_csv(path))
    dfs[-1]["GPU"] = gpu
# Merge all dfs into a single pd.Dataframe:
df_runtime = pd.concat(dfs)
df_runtime
# Out:
#                      Name Framework Precision  Problem Size  Iterations  \
# 0    MatrixMultiplication    Alpaka     float            32      8176.0
# 1    MatrixMultiplication    Alpaka     float            64      6900.0
# 2    MatrixMultiplication    Alpaka     float           128      4426.0
# 3    MatrixMultiplication    Alpaka     float           256      1168.0
# 4    MatrixMultiplication    Alpaka     float           512       176.0
# ..                    ...       ...       ...           ...         ...
# 239     PolyhedralGravity    Vulkan     float        255932      1000.0
# 240     PolyhedralGravity   OpenACC     float         14744      2439.0
# 241     PolyhedralGravity   OpenACC     float        255932       243.0
# 242     PolyhedralGravity    OpenCL     float         14744      6953.0
# 243     PolyhedralGravity    OpenCL     float        255932       526.0
#
#      Wall Clock Time      CPU Time   Kernel Time  Position Update Time  \
# 0       7.831260e+04  7.812443e+04  2.394853e+04                   NaN
# 1       1.129272e+05  1.126394e+05  3.995484e+04                   NaN
# 2       1.576464e+05  1.573337e+05  7.470166e+04                   NaN
# 3       6.227995e+05  6.217590e+05  4.624265e+05                   NaN
# 4       3.889060e+06  3.883924e+06  3.329796e+06                   NaN
# ..               ...           ...           ...                   ...
# 239     7.884460e+06  7.099255e+04           NaN                   NaN
# 240     2.875179e+05  2.874951e+05           NaN                   NaN
# 241     2.881376e+06  2.880761e+06           NaN                   NaN
# 242     9.924546e+04  9.922349e+04           NaN                   NaN
# 243     1.303882e+06  1.303870e+06           NaN                   NaN
#
#      Velocity Update Time  Force Update Time Time Unit Version  \
# 0                     NaN                NaN        ns     NaN
# 1                     NaN                NaN        ns     NaN
# 2                     NaN                NaN        ns     NaN
# 3                     NaN                NaN        ns     NaN
# 4                     NaN                NaN        ns     NaN
# ..                    ...                ...       ...     ...
# 239                   NaN                NaN        ns     NaN
# 240                   NaN                NaN        ns     NaN
# 241                   NaN                NaN        ns     NaN
# 242                   NaN                NaN        ns     NaN
# 243                   NaN                NaN        ns     NaN
#
#     Framework[Version]      GPU
# 0               Alpaka  RTX2080
# 1               Alpaka  RTX2080
# 2               Alpaka  RTX2080
# 3               Alpaka  RTX2080
# 4               Alpaka  RTX2080
# ..                 ...      ...
# 239             Vulkan  RTX5080
# 240            OpenACC  RTX5080
# 241            OpenACC  RTX5080
# 242             OpenCL  RTX5080
# 243             OpenCL  RTX5080
#
# [915 rows x 15 columns]

# %%
results_code_complexity = Path("../results/code-complexity/code-complexity.csv")
df_complexity = pd.read_csv(results_code_complexity)
df_complexity["n"] = df_complexity["n1"] + df_complexity["n2"]
df_complexity["N"] = df_complexity["N1"] + df_complexity["N2"]
df_complexity["V"] = df_complexity["N"] * np.log2(df_complexity["n"].replace(0, np.nan))
df_complexity["D"] = (df_complexity["n1"] / 2) * (df_complexity["N2"] / df_complexity["n2"].replace(0, np.nan))
df_complexity["E"] = df_complexity["D"] * df_complexity["V"]
df_complexity.rename(columns={"Framework": "Framework[Version]"}, inplace=True)
df_complexity
# Out:
#                     Name         Framework[Version]  SLOC   n1   n2    N1  \
# 0                 VecAdd                        CPP    30   37   42   183
# 1                 VecAdd                     Alpaka    83   44   96   487
# 2                 VecAdd                      Boost    49   51   57   322
# 3                 VecAdd                AdaptiveCpp    47   52   64   338
# 4                 VecAdd                       Cuda    76   61   48   399
# 5                 VecAdd                     Cublas    66   48   47   368
# 6                 VecAdd                    OpenACC    41   52   52   246
# 7                 VecAdd                     OpenCL   143   82   96   894
# 8                 VecAdd                     OpenMP    37   45   53   219
# 9                 VecAdd                     Vulkan   206   92  198  1394
# 10                VecAdd                     Kokkos    45   43   53   299
# 11  MatrixMultiplication                     Vulkan   266   93  225  1749
# 12  MatrixMultiplication                     OpenCL   195   89  112  1157
# 13  MatrixMultiplication                        CPP    48   45   59   292
# 14  MatrixMultiplication                     Alpaka   109   48  116   635
# 15  MatrixMultiplication                      Boost   106   57   97   618
# 16  MatrixMultiplication         AdaptiveCpp[Naive]    67   61   85   474
# 17  MatrixMultiplication  AdaptiveCpp[SharedMemory]    94   65  102   618
# 18  MatrixMultiplication                     Kokkos    64   50   74   448
# 19  MatrixMultiplication                     Cublas    66   47   55   374
# 20  MatrixMultiplication                Cuda[Naive]    82   69   67   581
# 21  MatrixMultiplication         Cuda[SharedMemory]   132   79  103   994
# 22  MatrixMultiplication                     OpenMP    52   47   71   333
# 23  MatrixMultiplication                    OpenACC    56   55   67   340
# 24                 NBody                     Vulkan   365   93  256  2336
# 25                 NBody                AdaptiveCpp   201   69  139  1331
# 26                 NBody                     Alpaka   246   55  164  1558
# 27                 NBody                      Boost   243   65  156  1434
# 28                 NBody                        CPP   107   53  100   674
# 29                 NBody                       Cuda   210   72  126  1507
# 30                 NBody                     Kokkos   213   72  134  1290
# 31                 NBody                     OpenMP   204   67  120  1266
# 32                 NBody                     OpenCL   341   95  175  2060
# 33     PolyhedralGravity                AdaptiveCpp   607   88  281  3765
# 34     PolyhedralGravity                       Cuda   718  100  299  4218
# 35     PolyhedralGravity                     Kokkos   551   89  250  3555
# 36     PolyhedralGravity                     OpenCL   764   96  352  4319
# 37     PolyhedralGravity                     Vulkan  1074  185  520  6021
# 38     PolyhedralGravity                     OpenMP   574   92  252  3442
# 39     PolyhedralGravity                    OpenACC   570   86  252  3452
# 40     PolyhedralGravity                     Vulkan  1074  185  520  6021
# 41     PolyhedralGravity               Slang-Vulkan   922  183  509  5077
# 42     PolyhedralGravity                 Slang-Cuda   807  100  344  4278
# 43     PolyhedralGravity                        CPP   541   79  239  3262
#
#       N2    n     N             V           D             E
# 0     89   79   272   1714.628364   39.202381  6.721751e+04
# 1    295  140   782   5575.099319   67.604167  3.768999e+05
# 2    187  108   509   3438.237739   83.657895  2.876357e+05
# 3    154  116   492   3374.126650   62.562500  2.110938e+05
# 4    172  109   571   3864.633249  109.291667  4.223722e+05
# 5    159   95   527   3462.313906   81.191489  2.811104e+05
# 6    123  104   369   2472.462256   61.500000  1.520564e+05
# 7    369  178  1263   9441.851323  157.593750  1.487977e+06
# 8    121   98   340   2249.001347   51.367925  1.155265e+05
# 9    769  290  2163  17693.143362  178.656566  3.160996e+06
# 10   157   96   456   3002.742900   63.688679  1.912407e+05
# 11   978  318  2727  22669.231819  202.120000  4.581905e+06
# 12   501  201  1658  12685.443704  199.058036  2.525140e+06
# 13   160  104   452   3028.598753   61.016949  1.847959e+05
# 14   405  164  1040   7651.854085   83.793103  6.411726e+05
# 15   356  154   974   7077.850091  104.597938  7.403285e+05
# 16   241  146   715   5140.724560   86.476471  4.445517e+05
# 17   326  167   944   6970.216852  103.872549  7.240142e+05
# 18   254  124   702   4881.845810   85.810811  4.189151e+05
# 19   180  102   554   3696.523639   76.909091  2.842963e+05
# 20   257  136   838   5939.293861  132.335821  7.859813e+05
# 21   486  182  1480  11111.536067  186.378641  2.070953e+06
# 22   192  118   525   3613.387601   63.549296  2.296282e+05
# 23   195  122   535   3707.944476   80.037313  2.967739e+05
# 24  1354  349  3690  31169.737105  245.941406  7.665929e+06
# 25   749  208  2080  16016.914614  185.902878  2.977591e+06
# 26   969  219  2527  19646.886900  162.484756  3.192320e+06
# 27   861  221  2295  17873.236374  179.375000  3.206012e+06
# 28   366  153  1040   7547.683356   96.990000  7.320498e+05
# 29   699  198  2206  16830.360704  199.714286  3.361263e+06
# 30   700  206  1990  15296.136049  188.059701  2.876587e+06
# 31   728  187  1994  15048.507553  203.233333  3.058358e+06
# 32   925  270  2985  24109.294557  251.071429  6.053155e+06
# 33  2270  369  6035  51463.323732  355.444840  1.829237e+07
# 34  2620  399  6838  59081.994874  438.127090  2.588542e+07
# 35  2010  339  5565  46774.612242  357.780000  1.673502e+07
# 36  2748  448  7067  62241.577234  374.727273  2.332362e+07
# 37  3749  705  9770  92438.654200  666.889423  6.164636e+07
# 38  2025  344  5467  46066.389414  369.642857  1.702811e+07
# 39  2022  338  5474  45986.414034  345.023810  1.586641e+07
# 40  3749  705  9770  92438.654200  666.889423  6.164636e+07
# 41  3201  692  8278  78099.852468  575.425344  4.494063e+07
# 42  2730  444  7008  61631.266391  396.802326  2.445543e+07
# 43  1955  318  5217  43368.310378  323.106695  1.401259e+07

# %%
# Merge df_results and df_complexity on ['Name', 'Framework']
df = pd.merge(df_runtime, df_complexity, on=["Name", "Framework[Version]"], how="inner")
#df = pd.merge(df_runtime, df_complexity, on=["Name", "Framework"], how="inner")
df = df.drop(columns=["Precision", "Iterations", "Time Unit"])
df
# Out:
#                      Name Framework  Problem Size  Wall Clock Time  \
# 0    MatrixMultiplication    Alpaka            32     7.831260e+04
# 1    MatrixMultiplication    Alpaka            64     1.129272e+05
# 2    MatrixMultiplication    Alpaka           128     1.576464e+05
# 3    MatrixMultiplication    Alpaka           256     6.227995e+05
# 4    MatrixMultiplication    Alpaka           512     3.889060e+06
# ..                    ...       ...           ...              ...
# 891     PolyhedralGravity    Vulkan        255932     7.884460e+06
# 892     PolyhedralGravity   OpenACC         14744     2.875179e+05
# 893     PolyhedralGravity   OpenACC        255932     2.881376e+06
# 894     PolyhedralGravity    OpenCL         14744     9.924546e+04
# 895     PolyhedralGravity    OpenCL        255932     1.303882e+06
#
#          CPU Time   Kernel Time  Position Update Time  Velocity Update Time  \
# 0    7.812443e+04  2.394853e+04                   NaN                   NaN
# 1    1.126394e+05  3.995484e+04                   NaN                   NaN
# 2    1.573337e+05  7.470166e+04                   NaN                   NaN
# 3    6.217590e+05  4.624265e+05                   NaN                   NaN
# 4    3.883924e+06  3.329796e+06                   NaN                   NaN
# ..            ...           ...                   ...                   ...
# 891  7.099255e+04           NaN                   NaN                   NaN
# 892  2.874951e+05           NaN                   NaN                   NaN
# 893  2.880761e+06           NaN                   NaN                   NaN
# 894  9.922349e+04           NaN                   NaN                   NaN
# 895  1.303870e+06           NaN                   NaN                   NaN
#
#      Force Update Time Version  ...  SLOC   n1   n2    N1    N2    n     N  \
# 0                  NaN     NaN  ...   109   48  116   635   405  164  1040
# 1                  NaN     NaN  ...   109   48  116   635   405  164  1040
# 2                  NaN     NaN  ...   109   48  116   635   405  164  1040
# 3                  NaN     NaN  ...   109   48  116   635   405  164  1040
# 4                  NaN     NaN  ...   109   48  116   635   405  164  1040
# ..                 ...     ...  ...   ...  ...  ...   ...   ...  ...   ...
# 891                NaN     NaN  ...  1074  185  520  6021  3749  705  9770
# 892                NaN     NaN  ...   570   86  252  3452  2022  338  5474
# 893                NaN     NaN  ...   570   86  252  3452  2022  338  5474
# 894                NaN     NaN  ...   764   96  352  4319  2748  448  7067
# 895                NaN     NaN  ...   764   96  352  4319  2748  448  7067
#
#                 V           D             E
# 0     7651.854085   83.793103  6.411726e+05
# 1     7651.854085   83.793103  6.411726e+05
# 2     7651.854085   83.793103  6.411726e+05
# 3     7651.854085   83.793103  6.411726e+05
# 4     7651.854085   83.793103  6.411726e+05
# ..            ...         ...           ...
# 891  92438.654200  666.889423  6.164636e+07
# 892  45986.414034  345.023810  1.586641e+07
# 893  45986.414034  345.023810  1.586641e+07
# 894  62241.577234  374.727273  2.332362e+07
# 895  62241.577234  374.727273  2.332362e+07
#
# [896 rows x 22 columns]

# %%
export_results = Path("../results/all_results.csv")
if not export_results.exists():
    df.to_csv(export_results, index=False)
    print("Results exported!")
else:
    print("Results already exported!")
# Out:
# Results already exported!

# %% [markdown]
# Plotting of the results

# %%
colors = matplotlib.colormaps["tab20"].colors
plt.figure(figsize=(8, 2))
for i, c in enumerate(colors):
    plt.scatter(i, 0, color=c, s=200)
    plt.text(i, 0.1, str(i), ha="center", va="bottom", fontsize=9)
plt.yticks([])
plt.xticks(range(len(colors)))
plt.xlim(-1, len(colors))
plt.title("tab20 colors with indices")
plt.grid(False)
plt.show()

# %%
df["Framework[Version]"].unique()
# Out:
# array(['Alpaka', 'OpenMP', 'Vulkan', 'AdaptiveCpp[Naive]',
#        'AdaptiveCpp[SharedMemory]', 'CPP', 'OpenCL', 'Boost', 'Kokkos',
#        'Cublas', 'Cuda[Naive]', 'Cuda[SharedMemory]', 'AdaptiveCpp',
#        'Cuda', 'OpenACC', 'Slang-Cuda', 'Slang-Vulkan'], dtype=object)

# %%
frameworks = [
    "Alpaka", "OpenMP", "Vulkan", "AdaptiveCpp[Naive]", "AdaptiveCpp-Shr",
    "CPP", "OpenCL", "Boost", "Kokkos", "Cublas", "Cuda", "Cuda-Shr",
    "OpenACC", "Slang-Cuda", "Slang-Vulkan"
]
tab20 = matplotlib.colormaps["tab20"].colors
color_map = {
    "CPP": tab20[0],

    "Vulkan": tab20[2],
    "Slang-Vulkan": tab20[3],

    "Cuda": tab20[8],
    "Cuda[Naive]": tab20[8],
    "Slang-Cuda": tab20[9],
    "Cuda-Shr": tab20[12],
    "Cuda[SharedMemory]": tab20[12],
    "Cublas": tab20[13],

    "AdaptiveCpp[Naive]": tab20[4],
    "AdaptiveCpp": tab20[4],
    "AdaptiveCpp[SharedMemory]": tab20[5],

    "OpenACC": tab20[14],
    "OpenMP": tab20[18],

    "Alpaka": tab20[10],

    "OpenCL": tab20[16],
    "Boost": tab20[17],

    "Kokkos": tab20[6],
}
name_markers = {
    "PolyhedralGravity": "s",
    "VecAdd": "+",
    "MatrixMultiplication": "x",
    "NBody": "o"
}

# %%
# Task: Remove all rows from the main dataframe `df` whose Framework[Version] ends with "[SharedMemory]".
if "Framework[Version]" in df.columns:
    df = df.loc[~df["Framework[Version]"].astype(str).str.contains(r"\[SharedMemory\]\s*$", na=False)].copy()

# %%
USE_FRAMEWORK = "Framework"
# USE_FRAMEWORK = "Framework[Version]"


def filter_and_normalize(df: pd.DataFrame,
                         name: str,
                         problem_size: int,
                         runtime: str = "Kernel Time",
                         exclude: str | list[str] = "Cublas") -> pd.DataFrame:
    """
    Filter by Name and Problem Size, exclude frameworks, and compute:
    - Application Efficiency [%]: normalized inverse of chosen runtime column (lower is better -> higher score)
      computed separately within each GPU group.
    """
    df = df.copy()
    required_cols = {USE_FRAMEWORK, "Name", "Problem Size", runtime, "GPU", "E", "SLOC"}
    missing = [c for c in required_cols if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # Filter by name and problem size
    out = df.loc[(df["Name"] == name) & (df["Problem Size"] == problem_size)].copy()

    # Exclude frameworks
    if exclude:
        excl = [exclude] if isinstance(exclude, str) else list(exclude)
        out = out.loc[~out[USE_FRAMEWORK].isin(excl)]

    # Drop columns not needed for the analysis if they exist
    to_drop = ["Name", "Problem Size"]
    existing_drop = [c for c in to_drop if c in out.columns]
    if existing_drop:
        out.drop(columns=existing_drop, inplace=True)

    # Application Efficiency per GPU: normalize inverse within each GPU group (best/fastest in GPU = 100)
    runtime_series = out[runtime].astype(float)
    min_per_gpu = runtime_series.groupby(out["GPU"]).transform("min")
    out["Application Efficiency [%]"] = (min_per_gpu / runtime_series) * 100.0

    # Calculate performance portability from the Application Efficiency (harmonic mean across GPUs)
    ae_per_fw_gpu = (
        out.groupby([USE_FRAMEWORK, "GPU"], as_index=False)["Application Efficiency [%]"]
        .mean()
        .rename(columns={"Application Efficiency [%]": "_AE"})
    )
    ae_per_fw_gpu["_inv_AE"] = np.where(ae_per_fw_gpu["_AE"] > 0.0, 1.0 / ae_per_fw_gpu["_AE"], np.nan)

    n_platforms_per_fw = ae_per_fw_gpu.groupby(USE_FRAMEWORK)["GPU"].nunique()
    inv_ae_sum_per_fw = ae_per_fw_gpu.groupby(USE_FRAMEWORK)["_inv_AE"].sum(min_count=1)

    pp_per_fw = (n_platforms_per_fw / inv_ae_sum_per_fw).replace([np.inf, -np.inf], np.nan)
    out["Performance Portability [%]"] = out[USE_FRAMEWORK].map(pp_per_fw)

    # Halstead Effort normalized to max=100
    e_series = out["E"].astype(float)
    sloc_series = out["SLOC"].astype(int)
    # get the halstead effort for the C++ implementation; df["Framework"] = "CPP
    # this not actually the min, but the values are the same independent of the GPU being used
    cpp_e = out[out[USE_FRAMEWORK] == "CPP"]["E"].astype(float).min()
    cpp_sloc = out[out[USE_FRAMEWORK] == "CPP"]["SLOC"].astype(float).min()
    max_e = e_series.max()
    out["Halstead Effort [%]"] = (e_series / cpp_e) * 100.0 if np.isfinite(
        max_e) and max_e != 0 else e_series
    out["SLOC Difference [1]"] = sloc_series - cpp_sloc
    out["SLOC Difference [%]"] = sloc_series / cpp_sloc * 100.0

    return out


def filter_and_concat(
        df: pd.DataFrame,
        queries: Iterable[Tuple[str, int, str | None]],
        exclude: str | list[str] = "Cublas",
) -> pd.DataFrame:
    """
    Run filter_and_normalize multiple times and concatenate results.
    Each query is a tuple of (name, problem_size, runtime). If runtime is None, defaults to "Kernel Time".
    The resulting dataframe will include the original Name and Problem Size for each query.
    """
    frames: list[pd.DataFrame] = []
    for q in queries:
        if len(q) != 3:
            raise ValueError("Each query must be a tuple: (name, problem_size, runtime)")
        name, problem_size, runtime = q
        rt = runtime if runtime is not None else "Kernel Time"
        out = filter_and_normalize(df, name=name, problem_size=problem_size, runtime=rt, exclude=exclude).copy()
        # Re-add the identifying columns
        out["Name"] = name
        out["Problem Size"] = problem_size
        out["Runtime Column"] = rt
        frames.append(out)

    if not frames:
        return pd.DataFrame(columns=["Name", "Problem Size", "Runtime Column"])

    return pd.concat(frames, ignore_index=True)

# %%
def plot(local_df, topic, x_axis, y1_axis, y1_axis_lim, y2_axis, y2_axis_lim, y3_axis, y3_axis_lim, sizes, markers):
    fig, ax_top = plt.subplots(
        1, 1,
        figsize=(6, 4)
    )

    ax_top = sns.scatterplot(
        data=local_df,
        x=x_axis,
        y=y1_axis,
        hue=USE_FRAMEWORK,
        size="Problem Size",
        sizes=sizes,
        palette=color_map,
        style="Name",
        markers=markers,
        s=140,
        ax=ax_top
    )
    ax_top.grid(True, linestyle="--")
    ax_top.set_ylim(y1_axis_lim[0], y1_axis_lim[1])
    ax_top.set_xlim(0, 105)
    ax_top.set_xlabel(x_axis, fontsize=18)
    ax_top.set_ylabel(y1_axis, fontsize=16, labelpad=14)
    ax_top.tick_params(axis="both", labelsize=12)

    # Move shared legend to the right outside the plot
    legend = ax_top.legend_
    if legend is not None:
        handles, labels = legend.legend_handles, [t.get_text() for t in legend.texts]
        legend.remove()
        leg = fig.legend(
            handles, labels,
            loc="center left",
            bbox_to_anchor=(0.9, 0.5),
            frameon=True
        )
        if leg is not None:
            for txt in leg.get_texts():
                txt.set_fontsize(12)
            if leg.get_title() is not None:
                leg.get_title().set_fontsize(13)

    fig.tight_layout(rect=(0.0, 0.0, 0.86, 1.0))
    plt.gcf().set_dpi(300)
    plt.show()

# %%
df_polyhedral = filter_and_concat(df, [("PolyhedralGravity", 14744, "Wall Clock Time"), ("PolyhedralGravity", 255932, "Wall Clock Time")])

local_df = df_polyhedral
topic = "Polyhedral Gravity Model"
x_axis = "Performance Portability [%]"
y1_axis = "Halstead Effort [%]"
y1_axis_lim = (100, 500)
y2_axis = "SLOC Difference [%]"
y2_axis_lim = (100, 500)
y3_axis = "SLOC Difference [1]"
y3_axis_lim = (0, 600)
sizes = [100, 300]
markers = ["h"]
plot(local_df, topic, x_axis, y1_axis, y1_axis_lim, y2_axis, y2_axis_lim, y3_axis, y3_axis_lim, sizes, markers)

# %%
df_nbody = filter_and_concat(df, [
    # ("NBody", 100, "Wall Clock Time"),
    ("NBody", 1000, "Wall Clock Time"),
    ("NBody", 10000, "Wall Clock Time")
])
df_nbody
# Out:
#       Framework  Wall Clock Time      CPU Time  Kernel Time  \
# 0        Alpaka     7.267148e+08  7.266952e+08          NaN
# 1        OpenMP     2.205317e+09  3.301654e+07          NaN
# 2        Vulkan     1.729809e+09  1.489783e+09          NaN
# 3   AdaptiveCpp     1.748662e+08  1.567495e+08          NaN
# 4           CPP     1.461081e+09  1.460777e+09          NaN
# ..          ...              ...           ...          ...
# 67       Vulkan     2.896616e+09  1.675916e+09          NaN
# 68        Boost     1.266736e+09  1.266540e+09          NaN
# 69       Alpaka     7.751177e+09  7.749993e+09          NaN
# 70       Kokkos     5.151393e+09  5.150571e+09          NaN
# 71         Cuda     1.424842e+09  1.424671e+09          NaN
#
#     Position Update Time  Velocity Update Time  Force Update Time Version  \
# 0           6.566434e+06          5.559130e+06       7.115348e+08     NaN
# 1           4.121700e+07          2.058304e+07       2.143367e+09     NaN
# 2           3.400522e+08          3.386466e+08       5.207502e+08     NaN
# 3           3.482918e+06          2.986541e+06       1.400197e+08     NaN
# 4           1.148279e+06          8.671750e+05       1.458999e+09     NaN
# ..                   ...                   ...                ...     ...
# 67          4.286849e+08          4.233644e+08       1.573877e+09     NaN
# 68          2.618528e+06          2.671680e+06       1.232895e+09     NaN
# 69          7.891748e+06          7.040903e+06       7.732930e+09     NaN
# 70          1.514837e+06          1.615498e+07       5.133009e+09     NaN
# 71          4.162656e+06          2.770240e+06       2.207067e+04     NaN
#
#    Framework[Version]      GPU  ...           D             E  \
# 0              Alpaka  RTX2080  ...  162.484756  3.192320e+06
# 1              OpenMP  RTX2080  ...  203.233333  3.058358e+06
# 2              Vulkan  RTX2080  ...  245.941406  7.665929e+06
# 3         AdaptiveCpp  RTX2080  ...  185.902878  2.977591e+06
# 4                 CPP  RTX2080  ...   96.990000  7.320498e+05
# ..                ...      ...  ...         ...           ...
# 67             Vulkan  RTX5080  ...  245.941406  7.665929e+06
# 68              Boost  RTX5080  ...  179.375000  3.206012e+06
# 69             Alpaka  RTX5080  ...  162.484756  3.192320e+06
# 70             Kokkos  RTX5080  ...  188.059701  2.876587e+06
# 71               Cuda  RTX5080  ...  199.714286  3.361263e+06
#
#     Application Efficiency [%]  Performance Portability [%]  \
# 0                    20.507658                    18.619861
# 1                     6.757859                     4.250007
# 2                     8.615531                     4.422279
# 3                    85.226396                    55.071379
# 4                    10.200132                     5.308730
# ..                         ...                          ...
# 67                   41.509855                    28.121934
# 68                   94.919671                    76.732035
# 69                   15.512241                    15.514882
# 70                   23.340892                    10.757808
# 71                   84.386991                    89.182706
#
#     Halstead Effort [%]  SLOC Difference [1]  SLOC Difference [%]   Name  \
# 0            436.079566                139.0           229.906542  NBody
# 1            417.780090                 97.0           190.654206  NBody
# 2           1047.186801                258.0           341.121495  NBody
# 3            406.746984                 94.0           187.850467  NBody
# 4            100.000000                  0.0           100.000000  NBody
# ..                  ...                  ...                  ...    ...
# 67          1047.186801                258.0           341.121495  NBody
# 68           437.949950                136.0           227.102804  NBody
# 69           436.079566                139.0           229.906542  NBody
# 70           392.949598                106.0           199.065421  NBody
# 71           459.157755                103.0           196.261682  NBody
#
#     Problem Size   Runtime Column
# 0           1000  Wall Clock Time
# 1           1000  Wall Clock Time
# 2           1000  Wall Clock Time
# 3           1000  Wall Clock Time
# 4           1000  Wall Clock Time
# ..           ...              ...
# 67         10000  Wall Clock Time
# 68         10000  Wall Clock Time
# 69         10000  Wall Clock Time
# 70         10000  Wall Clock Time
# 71         10000  Wall Clock Time
#
# [72 rows x 28 columns]

# %%
local_df = df_nbody
topic = "NBody Simulation"
x_axis = "Performance Portability [%]"
y1_axis = "Halstead Effort [%]"
y1_axis_lim = (100, 1250)
y2_axis = "SLOC Difference [%]"
y2_axis_lim = (100, 1250)
y3_axis = "SLOC Difference [1]"
y3_axis_lim = (0, 600)
sizes = [100, 300]
markers = ["o"]
plot(local_df, topic, x_axis, y1_axis, y1_axis_lim, y2_axis, y2_axis_lim, y3_axis, y3_axis_lim, sizes, markers)

# %%
df_mm = filter_and_concat(df, [
    ("MatrixMultiplication", 1024, "Wall Clock Time"),
    #("MatrixMultiplication", 2048, "Wall Clock Time"),
    #("MatrixMultiplication", 4096, "Wall Clock Time"),
    ("MatrixMultiplication", 8192, "Wall Clock Time")
])

# %%
local_df = df_mm
topic = "Matrix Multiplication"
x_axis = "Performance Portability [%]"
y1_axis = "Halstead Effort [%]"
y1_axis_lim = (100, 2500)
y2_axis = "SLOC Difference [%]"
y2_axis_lim = (100, 2500)
y3_axis = "SLOC Difference [1]"
y3_axis_lim = (0, 300)
sizes = [100, 400]
markers = ["s"]
plot(local_df, topic, x_axis, y1_axis, y1_axis_lim, y2_axis, y2_axis_lim, y3_axis, y3_axis_lim, sizes, markers)

# %%
df_mm2 = filter_and_concat(
    df,
    [
        # ("MatrixMultiplication", 1024, "Wall Clock Time"),
        # ("MatrixMultiplication", 2048, "Wall Clock Time"),
        # ("MatrixMultiplication", 4096, "Wall Clock Time"),
        ("MatrixMultiplication", 8192, "Wall Clock Time")
    ],
)

local_df = df_mm2.copy()

# Heatmap input: application efficiency per GPU (rows=framework, cols=GPU)
ae_pivot = (
    local_df.groupby([USE_FRAMEWORK, "GPU"], as_index=False)["Application Efficiency [%]"]
    .mean()
    .pivot(index=USE_FRAMEWORK, columns="GPU", values="Application Efficiency [%]")
)

# Order rows by performance portability (descending) computed from per-GPU AE harmonic mean
ae_per_fw_gpu = (
    local_df.groupby([USE_FRAMEWORK, "GPU"], as_index=False)["Application Efficiency [%]"]
    .mean()
    .rename(columns={"Application Efficiency [%]": "_AE"})
)
ae_per_fw_gpu["_inv_AE"] = np.where(ae_per_fw_gpu["_AE"] > 0.0, 1.0 / ae_per_fw_gpu["_AE"], np.nan)

n_platforms_per_fw = ae_per_fw_gpu.groupby(USE_FRAMEWORK)["GPU"].nunique()
inv_ae_sum_per_fw = ae_per_fw_gpu.groupby(USE_FRAMEWORK)["_inv_AE"].sum(min_count=1)
pp_per_fw = (n_platforms_per_fw / inv_ae_sum_per_fw).replace([np.inf, -np.inf], np.nan)

pp_order = (
    pp_per_fw.sort_values(ascending=False)
    .index.tolist()
)

ae_pivot = ae_pivot.reindex(pp_order)

plt.figure(figsize=(8, 5))
ax = sns.heatmap(
    ae_pivot,
    cmap="viridis",
    vmin=0,
    vmax=100,
    annot=True,
    fmt=".0f",
    linewidths=0.4,
    linecolor="white",
    cbar=False,
)
ax.set_xlabel("GPU", fontsize=12)
ax.set_ylabel(USE_FRAMEWORK, fontsize=12)

plt.tight_layout()
plt.gcf().set_dpi(300)
plt.show()

# %%
df_vec = filter_and_concat(df, [
    ("VecAdd", 1000000, "Wall Clock Time"),
    # ("VecAdd", 10000000, "Wall Clock Time"),
    ("VecAdd", 100000000, "Wall Clock Time")
])
df_vec
# Out:
#       Framework  Wall Clock Time      CPU Time   Kernel Time  \
# 0        Alpaka     1.559989e+06  1.559425e+06  3.219186e+04
# 1        OpenMP     6.286328e+06  2.506753e+06  4.589668e+06
# 2        Vulkan     1.365059e+07  1.143164e+07  4.553823e+05
# 3   AdaptiveCpp     3.954775e+06  3.337764e+06  3.377589e+05
# 4           CPP     1.666572e+06  1.666448e+06  1.628865e+05
# ..          ...              ...           ...           ...
# 69       Vulkan     2.172911e+09  2.070499e+09  2.170686e+06
# 70       Alpaka     1.826905e+08  1.816426e+08  1.404925e+06
# 71       Kokkos     5.113408e+08  5.113238e+08  2.056741e+06
# 72      OpenACC     2.769015e+08  2.768566e+08  7.764126e+07
# 73         Cuda     2.794554e+08  2.780909e+08  1.392971e+06
#
#     Position Update Time  Velocity Update Time  Force Update Time Version  \
# 0                    NaN                   NaN                NaN     NaN
# 1                    NaN                   NaN                NaN     NaN
# 2                    NaN                   NaN                NaN     NaN
# 3                    NaN                   NaN                NaN     NaN
# 4                    NaN                   NaN                NaN     NaN
# ..                   ...                   ...                ...     ...
# 69                   NaN                   NaN                NaN     NaN
# 70                   NaN                   NaN                NaN     NaN
# 71                   NaN                   NaN                NaN     NaN
# 72                   NaN                   NaN                NaN     NaN
# 73                   NaN                   NaN                NaN     NaN
#
#    Framework[Version]      GPU  ...           D             E  \
# 0              Alpaka  RTX2080  ...   67.604167  3.768999e+05
# 1              OpenMP  RTX2080  ...   51.367925  1.155265e+05
# 2              Vulkan  RTX2080  ...  178.656566  3.160996e+06
# 3         AdaptiveCpp  RTX2080  ...   62.562500  2.110938e+05
# 4                 CPP  RTX2080  ...   39.202381  6.721751e+04
# ..                ...      ...  ...         ...           ...
# 69             Vulkan  RTX5080  ...  178.656566  3.160996e+06
# 70             Alpaka  RTX5080  ...   67.604167  3.768999e+05
# 71             Kokkos  RTX5080  ...   63.688679  1.912407e+05
# 72            OpenACC  RTX5080  ...   61.500000  1.520564e+05
# 73               Cuda  RTX5080  ...  109.291667  4.223722e+05
#
#     Application Efficiency [%]  Performance Portability [%]  \
# 0                   100.000000                    99.042602
# 1                    24.815580                    23.422558
# 2                    11.427993                     6.620878
# 3                    39.445704                    30.350619
# 4                    93.604643                    60.499010
# ..                         ...                          ...
# 69                    8.407640                     9.441646
# 70                  100.000000                   100.000000
# 71                   35.727736                    34.640365
# 72                   65.976712                    63.837027
# 73                   65.373759                    62.509784
#
#     Halstead Effort [%]  SLOC Difference [1]  SLOC Difference [%]    Name  \
# 0            560.716872                 53.0           276.666667  VecAdd
# 1            171.869687                  7.0           123.333333  VecAdd
# 2           4702.637790                176.0           686.666667  VecAdd
# 3            314.045827                 17.0           156.666667  VecAdd
# 4            100.000000                  0.0           100.000000  VecAdd
# ..                  ...                  ...                  ...     ...
# 69          4702.637790                176.0           686.666667  VecAdd
# 70           560.716872                 53.0           276.666667  VecAdd
# 71           284.510267                 15.0           150.000000  VecAdd
# 72           226.215489                 11.0           136.666667  VecAdd
# 73           628.366302                 46.0           253.333333  VecAdd
#
#     Problem Size   Runtime Column
# 0        1000000  Wall Clock Time
# 1        1000000  Wall Clock Time
# 2        1000000  Wall Clock Time
# 3        1000000  Wall Clock Time
# 4        1000000  Wall Clock Time
# ..           ...              ...
# 69     100000000  Wall Clock Time
# 70     100000000  Wall Clock Time
# 71     100000000  Wall Clock Time
# 72     100000000  Wall Clock Time
# 73     100000000  Wall Clock Time
#
# [74 rows x 28 columns]

# %%
local_df = df_vec
topic = "Vector Addition"
x_axis = "Performance Portability [%]"
y1_axis = "Halstead Effort [%]"
y1_axis_lim = (100, 1000)
y2_axis = "SLOC Difference [%]"
y2_axis_lim = (100, 1000)
y3_axis = "SLOC Difference [1]"
y3_axis_lim = (0, 200)
sizes = [100, 400]
markers = ["P"]

plot(local_df, topic, x_axis, y1_axis, y1_axis_lim, y2_axis, y2_axis_lim, y3_axis, y3_axis_lim, sizes, markers)
